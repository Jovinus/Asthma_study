# %% [markdown]
# ## Import Library

# %%
# %% import package to use
import datatable
import pandas as pd
from IPython.display import display
import numpy as np
import os
from sklearn.metrics import accuracy_score
from imblearn.metrics import sensitivity_specificity_support
import matplotlib.pyplot as plt

from sklearn.metrics import log_loss
import xgboost as xgb
pd.set_option('display.max_columns', None)

from sklearn.metrics import roc_curve
from sklearn.metrics import RocCurveDisplay
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import PrecisionRecallDisplay
from sklearn.metrics import roc_auc_score
from sklearn.metrics import average_precision_score

from sklearn.metrics import confusion_matrix, auc, roc_curve, precision_recall_curve

import shap
# Out:
# <style type='text/css'>
# .datatable table.frame { margin-bottom: 0; }
# .datatable table.frame thead { border-bottom: none; }
# .datatable table.frame tr.coltypes td {  color: #FFFFFF;  line-height: 6px;  padding: 0 0.5em;}
# .datatable .bool    { background: #DDDD99; }
# .datatable .object  { background: #565656; }
# .datatable .int     { background: #5D9E5D; }
# .datatable .float   { background: #4040CC; }
# .datatable .str     { background: #CC4040; }
# .datatable .row_index {  background: var(--jp-border-color3);  border-right: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  font-size: 9px;}
# .datatable .frame tr.coltypes .row_index {  background: var(--jp-border-color0);}
# .datatable th:nth-child(2) { padding-left: 12px; }
# .datatable .hellipsis {  color: var(--jp-cell-editor-border-color);}
# .datatable .vellipsis {  background: var(--jp-layout-color0);  color: var(--jp-cell-editor-border-color);}
# .datatable .na {  color: var(--jp-cell-editor-border-color);  font-size: 80%;}
# .datatable .footer { font-size: 9px; }
# .datatable .frame_dimensions {  background: var(--jp-border-color3);  border-top: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  display: inline-block;  opacity: 0.6;  padding: 1px 10px 1px 5px;}
# </style>

# %%
def performances_hard_decision(y_test, y_proba, threshold_of_interest=0.5, youden=False):
   
    fpr, tpr, thresholds = roc_curve(y_test, y_proba)
    roc_auc = auc(fpr, tpr)
   
    print("AUROC: {:.3f}".format(roc_auc))
   
    precision, recall, _ = precision_recall_curve(y_test, y_proba)
    pr_auc = auc(recall, precision)
    
    print("AUPRC: {:.3f}".format(pr_auc))

    
    if(youden):
        threshold_of_interest = thresholds[np.argmax(tpr - fpr)]
    
    y_pred = y_proba >= threshold_of_interest
   
    tn, fp, fn, tp = confusion_matrix(y_test, y_pred).ravel()

    ppv = tp / (tp+fp)
    sensitivity = tp / (tp+fn)
    specificity = tn / (tn+fp)
    npv = tn / (tn+fn)
    accuracy = (tp+tn) / (tp+tn+fp+fn)
    f1 = (2 * ppv * sensitivity) / (ppv + sensitivity)
   
    print("specificity: {:.3f}".format(specificity))
    print("sensitivity: {:.3f}".format(sensitivity))
    print("PPV: {:.3f}".format(ppv))
    print("NPV: {:.3f}".format(npv))
    print("f1: {:.3f}".format(f1))
    print("accuracy: {:.3f}".format(accuracy))
    print("threshold: {:.3f}".format(threshold_of_interest))

# %%
def plot_roc_prc(y_hat, y):
    fpr, tpr, _ = roc_curve(y, y_hat, pos_label=1)
    roc_display = RocCurveDisplay(fpr=fpr, tpr=tpr)
    
    prec, recall, _ = precision_recall_curve(y, y_hat, pos_label=1)
    pr_display = PrecisionRecallDisplay(precision=prec, recall=recall)
    
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 10))

    roc_display.plot(ax=ax1)
    pr_display.plot(ax=ax2)
    plt.show()

# %%
# %% Load dataset
DATA_PATH = "/home/lkh256/Studio/Asthma/AI/data"
df_init = pd.read_excel(os.path.join(DATA_PATH, '20210913 AI asthma.xlsx'), sheet_name="746 (소아2 중복3 missing 8제거)")

print("Number of samples = {}".format(len(df_init)))

# %% Check missings
print("Check their is any missing variables in dataset: \n", df_init.isnull().sum())

# %%
from sklearn.model_selection import train_test_split

train_set, test_set = train_test_split(df_init,  
                                       random_state=1004, 
                                       stratify=df_init['Asthma'], 
                                       test_size=0.2)

print("Train set size = {}".format(len(train_set)))
print("Test set size = {}".format(len(test_set)))
# Out:
# Number of samples = 746
# Check their is any missing variables in dataset:
#  PtNo.                 0
# PtID                  0
# Name                  0
# IndexDate             0
# 지정의                   1
#                    ...
# 4.0_FEV1_90         739
# 4.0_FEF25_75_90     739
# 4.0_FVC_180         739
# 4.0_FEV1_180        739
# 4.0_FEF25_75_180    739
# Length: 124, dtype: int64
# Train set size = 596
# Test set size = 150

# %% [markdown]
# ## MBPT_result + PC20_16

# %%
import pickle
#### XGBoost
with open('./result/results_baseline_pc16.pickle', 'rb') as file_nm:
    results = pickle.load(file_nm)

df_results_xg = pd.DataFrame()
for condition in results:
    df_results_xg = pd.concat((df_results_xg, pd.DataFrame(results[condition])), axis=0)

columns = ['max_depth', 'learning_rate', 'lambda', 'gamma', 
           'val_scores', 'val_mse_loss', 'val_auroc', 'val_auprc', 
           'test_scores', 'test_mse_loss', 'test_auroc', 'test_auprc', 
           'test_ppv', 'test_npv', 'test_sensitivity', 'test_specificity', 
           'test_accuracy', 'test_f1', 'test_threshold']

xg_best_param = df_results_xg[df_results_xg['val_mean_mse'] == df_results_xg['val_mean_mse'].min()][columns].reset_index(drop=True)

baseline_pc16_metric = xg_best_param.copy()

display(xg_best_param.head(1))
# Out:
#    max_depth  learning_rate  lambda  gamma  val_scores  val_mse_loss  \
# 0          1          0.001       3    0.0    0.816667      0.469887
#
#    val_auroc  val_auprc  test_scores  test_mse_loss  test_auroc  test_auprc  \
# 0    0.77228   0.698876         0.86       0.391512    0.839934    0.774432
#
#    test_ppv  test_npv  test_sensitivity  test_specificity  test_accuracy  \
# 0   0.93617  0.834951          0.721311          0.966292       0.866667
#
#     test_f1  test_threshold
# 0  0.814815        0.496981

# %%
import xgboost as xgb

params = {'objective': "binary:logistic", 
          'eval_metric': 'logloss',
          'tree_method': 'gpu_hist', 
          'gpu_id': '0',
          'learning_rate': 0.001, 
          'max_depth': 1,
          'lambda': 3,
          'gamma': 0}

feature_mask = ['MBPT_result', 'PC20_16']

X_train = train_set[feature_mask].values
y_train = train_set['Asthma'].values
dtrain = xgb.DMatrix(X_train, label=y_train)

X_test = test_set[feature_mask].values
y_test = test_set['Asthma'].values
dtest = xgb.DMatrix(X_test, label=y_test)


model_xgb = xgb.train(params, dtrain, 
                    num_boost_round=20000, 
                    evals=[(dtest, 'test')], 
                    verbose_eval=0, 
                    early_stopping_rounds=1000)

print("Train accuracy", accuracy_score(y_train, model_xgb.predict(dtrain) > 0.5))
print("Test accuracy", accuracy_score(y_test, model_xgb.predict(dtest) > 0.5))
print("Train neg_loss : ", log_loss(y_pred=model_xgb.predict(dtrain), y_true=y_train))
print("Test neg_loss", log_loss(y_pred=model_xgb.predict(dtest), y_true=y_test))

y_hat = model_xgb.predict(dtest)

print(performances_hard_decision(y_test, y_hat, youden=True))

plot_roc_prc(y_hat, y_test)

explainer = shap.TreeExplainer(model_xgb)
shap_values = explainer.shap_values(X_test)

shap.summary_plot(shap_values, X_test, plot_type="bar", feature_names=feature_mask, plot_size=(10, 10))

shap.summary_plot(shap_values, X_test, feature_names=feature_mask, plot_size=(10, 10))
# Out:
# Train accuracy 0.8557046979865772
# Test accuracy 0.86
# Train neg_loss :  0.3883477821946144
# Test neg_loss 0.39714720748364923
# AUROC: 0.839
# AUPRC: 0.864
# specificity: 0.966
# sensitivity: 0.721
# PPV: 0.936
# NPV: 0.835
# f1: 0.815
# accuracy: 0.867
# threshold: 0.342
# None

# %% [markdown]
# ## MBPT_result + FeNO

# %%
import pickle
#### XGBoost
with open('./result/results_baseline_FeNO.pickle', 'rb') as file_nm:
    results = pickle.load(file_nm)

df_results_xg = pd.DataFrame()
for condition in results:
    df_results_xg = pd.concat((df_results_xg, pd.DataFrame(results[condition])), axis=0)

columns = ['max_depth', 'learning_rate', 'lambda', 'gamma', 
           'val_scores', 'val_mse_loss', 'val_auroc', 'val_auprc', 
           'test_scores', 'test_mse_loss', 'test_auroc', 'test_auprc', 
           'test_ppv', 'test_npv', 'test_sensitivity', 'test_specificity', 
           'test_accuracy', 'test_f1', 'test_threshold']

xg_best_param = df_results_xg[df_results_xg['val_mean_mse'] == df_results_xg['val_mean_mse'].min()][columns].reset_index(drop=True)

baseline_feno_metric = xg_best_param.copy()

display(xg_best_param.head(1))
# Out:
#    max_depth  learning_rate  lambda  gamma  val_scores  val_mse_loss  \
# 0          1          0.001       1    0.3    0.883333      0.313559
#
#    val_auroc  val_auprc  test_scores  test_mse_loss  test_auroc  test_auprc  \
# 0   0.942708   0.922499     0.846667       0.359549    0.900718    0.891047
#
#    test_ppv  test_npv  test_sensitivity  test_specificity  test_accuracy  \
# 0  0.830508  0.868132          0.803279           0.88764       0.853333
#
#     test_f1  test_threshold
# 0  0.816667        0.629577

# %%
import xgboost as xgb

params = {'objective': "binary:logistic", 
          'eval_metric': 'logloss',
          'tree_method': 'gpu_hist', 
          'gpu_id': '0',
          'learning_rate': 0.001, 
          'max_depth': 1,
          'lambda': 1,
          'gamma': 0.3}

feature_mask = ['MBPT_result', 'FeNO']

X_train = train_set[feature_mask].values
y_train = train_set['Asthma'].values
dtrain = xgb.DMatrix(X_train, label=y_train)

X_test = test_set[feature_mask].values
y_test = test_set['Asthma'].values
dtest = xgb.DMatrix(X_test, label=y_test)


model_xgb = xgb.train(params, dtrain, 
                    num_boost_round=20000, 
                    evals=[(dtest, 'test')], 
                    verbose_eval=0, 
                    early_stopping_rounds=1000)

print("Train accuracy", accuracy_score(y_train, model_xgb.predict(dtrain) > 0.5))
print("Test accuracy", accuracy_score(y_test, model_xgb.predict(dtest) > 0.5))
print("Train neg_loss : ", log_loss(y_pred=model_xgb.predict(dtrain), y_true=y_train))
print("Test neg_loss", log_loss(y_pred=model_xgb.predict(dtest), y_true=y_test))

y_hat = model_xgb.predict(dtest)

print(performances_hard_decision(y_test, y_hat, youden=True))

plot_roc_prc(y_hat, y_test)

explainer = shap.TreeExplainer(model_xgb)
shap_values = explainer.shap_values(X_test)

shap.summary_plot(shap_values, X_test, plot_type="bar", feature_names=feature_mask, plot_size=(10, 10))

shap.summary_plot(shap_values, X_test, feature_names=feature_mask, plot_size=(10, 10))
# Out:
# Train accuracy 0.8741610738255033
# Test accuracy 0.8533333333333334
# Train neg_loss :  0.3355295977448957
# Test neg_loss 0.36418945973118144
# AUROC: 0.899
# AUPRC: 0.905
# specificity: 0.888
# sensitivity: 0.803
# PPV: 0.831
# NPV: 0.868
# f1: 0.817
# accuracy: 0.853
# threshold: 0.640
# None

# %% [markdown]
# ## MBPT_result + ISE_Eos

# %%
import pickle
#### XGBoost
with open('./result/results_baseline_ISE.pickle', 'rb') as file_nm:
    results = pickle.load(file_nm)

df_results_xg = pd.DataFrame()
for condition in results:
    df_results_xg = pd.concat((df_results_xg, pd.DataFrame(results[condition])), axis=0)

columns = ['max_depth', 'learning_rate', 'lambda', 'gamma', 
           'val_scores', 'val_mse_loss', 'val_auroc', 'val_auprc', 
           'test_scores', 'test_mse_loss', 'test_auroc', 'test_auprc', 
           'test_ppv', 'test_npv', 'test_sensitivity', 'test_specificity', 
           'test_accuracy', 'test_f1', 'test_threshold']

xg_best_param = df_results_xg[df_results_xg['val_mean_mse'] == df_results_xg['val_mean_mse'].min()][columns].reset_index(drop=True)

baseline_ise_metric = xg_best_param.copy()

display(xg_best_param.head(1))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_831665/3179280724.py in <module>
#       6 df_results_xg = pd.DataFrame()
#       7 for condition in results:
# ----> 8     df_results_xg = pd.concat((df_results_xg, pd.DataFrame(results[condition])), axis=0)
#       9
#      10 columns = ['max_depth', 'learning_rate', 'lambda', 'gamma',
#
# ~/anaconda3/envs/torch/lib/python3.8/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     466
#     467         elif isinstance(data, dict):
# --> 468             mgr = init_dict(data, index, columns, dtype=dtype)
#     469         elif isinstance(data, ma.MaskedArray):
#     470             import numpy.ma.mrecords as mrecords
#
# ~/anaconda3/envs/torch/lib/python3.8/site-packages/pandas/core/internals/construction.py in init_dict(data, index, columns, dtype)
#     281             arr if not is_datetime64tz_dtype(arr) else arr.copy() for arr in arrays
#     282         ]
# --> 283     return arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     284
#     285
#
# ~/anaconda3/envs/torch/lib/python3.8/site-packages/pandas/core/internals/construction.py in arrays_to_mgr(arrays, arr_names, index, columns, dtype, verify_integrity)
#      76         # figure out the index, if necessary
#      77         if index is None:
# ---> 78             index = extract_index(arrays)
#      79         else:
#      80             index = ensure_index(index)
#
# ~/anaconda3/envs/torch/lib/python3.8/site-packages/pandas/core/internals/construction.py in extract_index(data)
#     395             lengths = list(set(raw_lengths))
#     396             if len(lengths) > 1:
# --> 397                 raise ValueError("arrays must all be same length")
#     398
#     399             if have_dicts:
#
# ValueError: arrays must all be same length

# %%
import xgboost as xgb

params = {'objective': "binary:logistic", 
          'eval_metric': 'logloss',
          'tree_method': 'gpu_hist', 
          'gpu_id': '0',
          'learning_rate': 0.001, 
          'max_depth': 1,
          'lambda': 3,
          'gamma': 0}

feature_mask = ['MBPT_result', 'ISE_Eos']

X_train = train_set[feature_mask].values
y_train = train_set['Asthma'].values
dtrain = xgb.DMatrix(X_train, label=y_train)

X_test = test_set[feature_mask].values
y_test = test_set['Asthma'].values
dtest = xgb.DMatrix(X_test, label=y_test)


model_xgb = xgb.train(params, dtrain, 
                    num_boost_round=20000, 
                    evals=[(dtest, 'test')], 
                    verbose_eval=0, 
                    early_stopping_rounds=1000)

print("Train accuracy", accuracy_score(y_train, model_xgb.predict(dtrain) > 0.5))
print("Test accuracy", accuracy_score(y_test, model_xgb.predict(dtest) > 0.5))
print("Train neg_loss : ", log_loss(y_pred=model_xgb.predict(dtrain), y_true=y_train))
print("Test neg_loss", log_loss(y_pred=model_xgb.predict(dtest), y_true=y_test))

y_hat = model_xgb.predict(dtest)

print(performances_hard_decision(y_test, y_hat, youden=True))

plot_roc_prc(y_hat, y_test)

explainer = shap.TreeExplainer(model_xgb)
shap_values = explainer.shap_values(X_test)

shap.summary_plot(shap_values, X_test, plot_type="bar", feature_names=feature_mask, plot_size=(10, 10))

shap.summary_plot(shap_values, X_test, feature_names=feature_mask, plot_size=(10, 10))
# Out:
# Train accuracy 0.8741610738255033
# Test accuracy 0.88
# Train neg_loss :  0.3325506062028092
# Test neg_loss 0.32628148048184813
# AUROC: 0.926
# AUPRC: 0.921
# specificity: 0.910
# sensitivity: 0.836
# PPV: 0.864
# NPV: 0.890
# f1: 0.850
# accuracy: 0.880
# threshold: 0.516
# None

# %% [markdown]
# ## MBPT_result + FeNO + ISE

# %%
import pickle
#### XGBoost
with open('./result/results_baseline_FeNO_ISE.pickle', 'rb') as file_nm:
    results = pickle.load(file_nm)

df_results_xg = pd.DataFrame()
for condition in results:
    df_results_xg = pd.concat((df_results_xg, pd.DataFrame(results[condition])), axis=0)

columns = ['max_depth', 'learning_rate', 'lambda', 'gamma', 
           'val_scores', 'val_mse_loss', 'val_auroc', 'val_auprc', 
           'test_scores', 'test_mse_loss', 'test_auroc', 'test_auprc', 
           'test_ppv', 'test_npv', 'test_sensitivity', 'test_specificity', 
           'test_accuracy', 'test_f1', 'test_threshold']

xg_best_param = df_results_xg[df_results_xg['val_mean_mse'] == df_results_xg['val_mean_mse'].min()][columns].reset_index(drop=True)

baseline_feno_ise_metric = xg_best_param.copy()

display(xg_best_param.head(1))
# Out:
#    max_depth  learning_rate  lambda  gamma  val_scores  val_mse_loss  \
# 0          1          0.001       2    0.3         0.9      0.340946
#
#    val_auroc  val_auprc  test_scores  test_mse_loss  test_auroc  test_auprc  \
# 0   0.885995     0.8916         0.86       0.353447    0.908915    0.904881
#
#    test_ppv  test_npv  test_sensitivity  test_specificity  test_accuracy  \
# 0   0.83871  0.897727          0.852459           0.88764       0.873333
#
#     test_f1  test_threshold
# 0  0.845528          0.4669

# %%
import xgboost as xgb

params = {'objective': "binary:logistic", 
          'eval_metric': 'logloss',
          'tree_method': 'gpu_hist', 
          'gpu_id': '0',
          'learning_rate': 0.001, 
          'max_depth': 1,
          'lambda': 2,
          'gamma': 0.3}

feature_mask = ['MBPT_result', 'FeNO', 'ISE_Eos']

X_train = train_set[feature_mask].values
y_train = train_set['Asthma'].values
dtrain = xgb.DMatrix(X_train, label=y_train)

X_test = test_set[feature_mask].values
y_test = test_set['Asthma'].values
dtest = xgb.DMatrix(X_test, label=y_test)


model_xgb = xgb.train(params, dtrain, 
                    num_boost_round=20000, 
                    evals=[(dtest, 'test')], 
                    verbose_eval=0, 
                    early_stopping_rounds=1000)

print("Train accuracy", accuracy_score(y_train, model_xgb.predict(dtrain) > 0.5))
print("Test accuracy", accuracy_score(y_test, model_xgb.predict(dtest) > 0.5))
print("Train neg_loss : ", log_loss(y_pred=model_xgb.predict(dtrain), y_true=y_train))
print("Test neg_loss", log_loss(y_pred=model_xgb.predict(dtest), y_true=y_test))

y_hat = model_xgb.predict(dtest)

print(performances_hard_decision(y_test, y_hat, youden=True))

plot_roc_prc(y_hat, y_test)

explainer = shap.TreeExplainer(model_xgb)
shap_values = explainer.shap_values(X_test)

shap.summary_plot(shap_values, X_test, plot_type="bar", feature_names=feature_mask, plot_size=(10, 10))

shap.summary_plot(shap_values, X_test, feature_names=feature_mask, plot_size=(10, 10))
# Out:
# Train accuracy 0.8859060402684564
# Test accuracy 0.88
# Train neg_loss :  0.31426800965900287
# Test neg_loss 0.336862629186362
# AUROC: 0.918
# AUPRC: 0.917
# specificity: 0.933
# sensitivity: 0.820
# PPV: 0.893
# NPV: 0.883
# f1: 0.855
# accuracy: 0.887
# threshold: 0.665
# None

# %% [markdown]
# ## MBPT_text

# %%
import pickle
#### XGBoost
with open('./result/results_mbpt_txt.pickle', 'rb') as file_nm:
    results = pickle.load(file_nm)

df_results_xg = pd.DataFrame()
for condition in results:
    df_results_xg = pd.concat((df_results_xg, pd.DataFrame(results[condition])), axis=0)

columns = ['max_depth', 'learning_rate', 'lambda', 'gamma', 
           'val_scores', 'val_mse_loss', 'val_auroc', 'val_auprc', 
           'test_scores', 'test_mse_loss', 'test_auroc', 'test_auprc', 
           'test_ppv', 'test_npv', 'test_sensitivity', 'test_specificity', 
           'test_accuracy', 'test_f1', 'test_threshold']

xg_best_param = df_results_xg[df_results_xg['val_mean_mse'] == df_results_xg['val_mean_mse'].min()][columns].reset_index(drop=True)

mbpt_txt_metric = xg_best_param.copy()

display(xg_best_param.head(1))
# Out:
#    max_depth  learning_rate  lambda  gamma  val_scores  val_mse_loss  \
# 0          2          0.001       3    0.3    0.866667      0.362453
#
#    val_auroc  val_auprc  test_scores  test_mse_loss  test_auroc  test_auprc  \
# 0   0.925637     0.8981         0.86       0.373876    0.912139    0.883355
#
#    test_ppv  test_npv  test_sensitivity  test_specificity  test_accuracy  \
# 0  0.903846  0.857143          0.770492           0.94382       0.873333
#
#     test_f1  test_threshold
# 0  0.831858        0.542827

# %%
import xgboost as xgb
import re

params = {'objective': "binary:logistic", 
          'eval_metric': 'logloss',
          'tree_method': 'gpu_hist', 
          'gpu_id': '0',
          'learning_rate': 0.001, 
          'max_depth': 2,
          'lambda': 3,
          'gamma': 0.3}

baseline_txt = [i for i in df_init.columns if "baseline" in i]
subs = r"0.05|0.5|2.0|8.0|16.0|32.0"
mbpt_txt = [x for x in df_init.columns if re.search(subs, str(x))]

feature_mask = baseline_txt + mbpt_txt

X_train = train_set[feature_mask].values
y_train = train_set['Asthma'].values
dtrain = xgb.DMatrix(X_train, label=y_train)

X_test = test_set[feature_mask].values
y_test = test_set['Asthma'].values
dtest = xgb.DMatrix(X_test, label=y_test)


model_xgb = xgb.train(params, dtrain, 
                    num_boost_round=20000, 
                    evals=[(dtest, 'test')], 
                    verbose_eval=0, 
                    early_stopping_rounds=1000)

print("Train accuracy", accuracy_score(y_train, model_xgb.predict(dtrain) > 0.5))
print("Test accuracy", accuracy_score(y_test, model_xgb.predict(dtest) > 0.5))
print("Train neg_loss : ", log_loss(y_pred=model_xgb.predict(dtrain), y_true=y_train))
print("Test neg_loss", log_loss(y_pred=model_xgb.predict(dtest), y_true=y_test))

y_hat = model_xgb.predict(dtest)

print(performances_hard_decision(y_test, y_hat, youden=True))

plot_roc_prc(y_hat, y_test)

explainer = shap.TreeExplainer(model_xgb)
shap_values = explainer.shap_values(X_test)

shap.summary_plot(shap_values, X_test, plot_type="bar", feature_names=feature_mask, plot_size=(10, 10))

shap.summary_plot(shap_values, X_test, feature_names=feature_mask, plot_size=(10, 10))
# Out:
# Train accuracy 0.9261744966442953
# Test accuracy 0.86
# Train neg_loss :  0.21353523741945904
# Test neg_loss 0.3592665207859439
# AUROC: 0.918
# AUPRC: 0.899
# specificity: 0.865
# sensitivity: 0.852
# PPV: 0.812
# NPV: 0.895
# f1: 0.832
# accuracy: 0.860
# threshold: 0.373
# None

# %% [markdown]
# ## MBPT_text + ISE_Eos

# %%
import pickle
#### XGBoost
with open('./result/results_mbpt_txt_ISE.pickle', 'rb') as file_nm:
    results = pickle.load(file_nm)

df_results_xg = pd.DataFrame()
for condition in results:
    df_results_xg = pd.concat((df_results_xg, pd.DataFrame(results[condition])), axis=0)

columns = ['max_depth', 'learning_rate', 'lambda', 'gamma', 
           'val_scores', 'val_mse_loss', 'val_auroc', 'val_auprc', 
           'test_scores', 'test_mse_loss', 'test_auroc', 'test_auprc', 
           'test_ppv', 'test_npv', 'test_sensitivity', 'test_specificity', 
           'test_accuracy', 'test_f1', 'test_threshold']

xg_best_param = df_results_xg[df_results_xg['val_mean_mse'] == df_results_xg['val_mean_mse'].min()][columns].reset_index(drop=True)

mbpt_txt_ise_metric = xg_best_param.copy()

display(xg_best_param.head(1))
# Out:
#    max_depth  learning_rate  lambda  gamma  val_scores  val_mse_loss  \
# 0          2          0.001       3    0.0    0.866667      0.306417
#
#    val_auroc  val_auprc  test_scores  test_mse_loss  test_auroc  test_auprc  \
# 0    0.94647    0.91726     0.886667       0.339049    0.922453    0.910542
#
#    test_ppv  test_npv  test_sensitivity  test_specificity  test_accuracy  \
# 0  0.820896  0.927711          0.901639          0.865169           0.88
#
#     test_f1  test_threshold
# 0  0.859375         0.27957

# %%
import xgboost as xgb
import re

params = {'objective': "binary:logistic", 
          'eval_metric': 'logloss',
          'tree_method': 'gpu_hist', 
          'gpu_id': '0',
          'learning_rate': 0.001, 
          'max_depth': 2,
          'lambda': 3,
          'gamma': 0.0}

baseline = ['ISE_Eos']
baseline_txt = [i for i in df_init.columns if "baseline" in i]
subs = r"0.05|0.5|2.0|8.0|16.0|32.0"
mbpt_txt = [x for x in df_init.columns if re.search(subs, str(x))]

feature_mask = baseline + baseline_txt + mbpt_txt

X_train = train_set[feature_mask].values
y_train = train_set['Asthma'].values
dtrain = xgb.DMatrix(X_train, label=y_train)

X_test = test_set[feature_mask].values
y_test = test_set['Asthma'].values
dtest = xgb.DMatrix(X_test, label=y_test)


model_xgb = xgb.train(params, dtrain, 
                    num_boost_round=20000, 
                    evals=[(dtest, 'test')], 
                    verbose_eval=0, 
                    early_stopping_rounds=1000)

print("Train accuracy", accuracy_score(y_train, model_xgb.predict(dtrain) > 0.5))
print("Test accuracy", accuracy_score(y_test, model_xgb.predict(dtest) > 0.5))
print("Train neg_loss : ", log_loss(y_pred=model_xgb.predict(dtrain), y_true=y_train))
print("Test neg_loss", log_loss(y_pred=model_xgb.predict(dtest), y_true=y_test))

y_hat = model_xgb.predict(dtest)

print(performances_hard_decision(y_test, y_hat, youden=True))

plot_roc_prc(y_hat, y_test)

explainer = shap.TreeExplainer(model_xgb)
shap_values = explainer.shap_values(X_test)

shap.summary_plot(shap_values, X_test, plot_type="bar", feature_names=feature_mask, plot_size=(10, 10))

shap.summary_plot(shap_values, X_test, feature_names=feature_mask, plot_size=(10, 10))
# Out:
# Train accuracy 0.9144295302013423
# Test accuracy 0.8733333333333333
# Train neg_loss :  0.23847966745336407
# Test neg_loss 0.3380866506882012
# AUROC: 0.923
# AUPRC: 0.906
# specificity: 0.888
# sensitivity: 0.852
# PPV: 0.839
# NPV: 0.898
# f1: 0.846
# accuracy: 0.873
# threshold: 0.385
# None

# %% [markdown]
# ## MBPT_text + FeNO

# %%
import pickle
#### XGBoost
with open('./result/results_mbpt_txt_FeNO.pickle', 'rb') as file_nm:
    results = pickle.load(file_nm)

df_results_xg = pd.DataFrame()
for condition in results:
    df_results_xg = pd.concat((df_results_xg, pd.DataFrame(results[condition])), axis=0)

columns = ['max_depth', 'learning_rate', 'lambda', 'gamma', 
           'val_scores', 'val_mse_loss', 'val_auroc', 'val_auprc', 
           'test_scores', 'test_mse_loss', 'test_auroc', 'test_auprc', 
           'test_ppv', 'test_npv', 'test_sensitivity', 'test_specificity', 
           'test_accuracy', 'test_f1', 'test_threshold']

xg_best_param = df_results_xg[df_results_xg['val_mean_mse'] == df_results_xg['val_mean_mse'].min()][columns].reset_index(drop=True)

mbpt_txt_feno_metric = xg_best_param.copy()

display(xg_best_param.head(1))
# Out:
#    max_depth  learning_rate  lambda  gamma  val_scores  val_mse_loss  \
# 0          2          0.001       3    0.3    0.783333      0.424579
#
#    val_auroc  val_auprc  test_scores  test_mse_loss  test_auroc  test_auprc  \
# 0   0.886863   0.875911     0.826667       0.397431    0.903481    0.887574
#
#    test_ppv  test_npv  test_sensitivity  test_specificity  test_accuracy  \
# 0  0.824561  0.849462          0.770492           0.88764           0.84
#
#    test_f1  test_threshold
# 0  0.79661        0.432716

# %%
import xgboost as xgb
import re

params = {'objective': "binary:logistic", 
          'eval_metric': 'logloss',
          'tree_method': 'gpu_hist', 
          'gpu_id': '0',
          'learning_rate': 0.001, 
          'max_depth': 2,
          'lambda': 3,
          'gamma': 0.3}

baseline = ['FeNO']
baseline_txt = [i for i in df_init.columns if "baseline" in i]
subs = r"0.05|0.5|2.0|8.0|16.0|32.0"
mbpt_txt = [x for x in df_init.columns if re.search(subs, str(x))]

feature_mask = baseline + baseline_txt + mbpt_txt

X_train = train_set[feature_mask].values
y_train = train_set['Asthma'].values
dtrain = xgb.DMatrix(X_train, label=y_train)

X_test = test_set[feature_mask].values
y_test = test_set['Asthma'].values
dtest = xgb.DMatrix(X_test, label=y_test)


model_xgb = xgb.train(params, dtrain, 
                    num_boost_round=20000, 
                    evals=[(dtest, 'test')], 
                    verbose_eval=0, 
                    early_stopping_rounds=1000)

print("Train accuracy", accuracy_score(y_train, model_xgb.predict(dtrain) > 0.5))
print("Test accuracy", accuracy_score(y_test, model_xgb.predict(dtest) > 0.5))
print("Train neg_loss : ", log_loss(y_pred=model_xgb.predict(dtrain), y_true=y_train))
print("Test neg_loss", log_loss(y_pred=model_xgb.predict(dtest), y_true=y_test))

y_hat = model_xgb.predict(dtest)

print(performances_hard_decision(y_test, y_hat, youden=True))

plot_roc_prc(y_hat, y_test)

explainer = shap.TreeExplainer(model_xgb)
shap_values = explainer.shap_values(X_test)

shap.summary_plot(shap_values, X_test, plot_type="bar", feature_names=feature_mask, plot_size=(10, 10))

shap.summary_plot(shap_values, X_test, feature_names=feature_mask, plot_size=(10, 10))
# Out:
# Train accuracy 0.9043624161073825
# Test accuracy 0.84
# Train neg_loss :  0.263233311124296
# Test neg_loss 0.39007678419351577
# AUROC: 0.899
# AUPRC: 0.883
# specificity: 0.876
# sensitivity: 0.803
# PPV: 0.817
# NPV: 0.867
# f1: 0.810
# accuracy: 0.847
# threshold: 0.422
# None

# %% [markdown]
# ## MBPT_text + FeNO + ISE_Eos

# %%
import pickle
#### XGBoost
with open('./result/results_mbpt_txt_FeNO_ISE.pickle', 'rb') as file_nm:
    results = pickle.load(file_nm)

df_results_xg = pd.DataFrame()
for condition in results:
    df_results_xg = pd.concat((df_results_xg, pd.DataFrame(results[condition])), axis=0)

columns = ['max_depth', 'learning_rate', 'lambda', 'gamma', 
           'val_scores', 'val_mse_loss', 'val_auroc', 'val_auprc', 
           'test_scores', 'test_mse_loss', 'test_auroc', 'test_auprc', 
           'test_ppv', 'test_npv', 'test_sensitivity', 'test_specificity', 
           'test_accuracy', 'test_f1', 'test_threshold']

xg_best_param = df_results_xg[df_results_xg['val_mean_mse'] == df_results_xg['val_mean_mse'].min()][columns].reset_index(drop=True)

mbpt_txt_feno_ise_metric = xg_best_param.copy()

display(xg_best_param.head(1))
# Out:
#    max_depth  learning_rate  lambda  gamma  val_scores  val_mse_loss  \
# 0          2          0.001       2    0.2       0.875       0.33351
#
#    val_auroc  val_auprc  test_scores  test_mse_loss  test_auroc  test_auprc  \
# 0   0.928241   0.917257     0.833333       0.350706    0.916375    0.902983
#
#    test_ppv  test_npv  test_sensitivity  test_specificity  test_accuracy  \
# 0   0.80303  0.904762          0.868852          0.853933           0.86
#
#     test_f1  test_threshold
# 0  0.834646        0.345759

# %%
import xgboost as xgb
import re

params = {'objective': "binary:logistic", 
          'eval_metric': 'logloss',
          'tree_method': 'gpu_hist', 
          'gpu_id': '0',
          'learning_rate': 0.001, 
          'max_depth': 2,
          'lambda': 2,
          'gamma': 0.2}

baseline = ['FeNO', 'ISE_Eos']
baseline_txt = [i for i in df_init.columns if "baseline" in i]
subs = r"0.05|0.5|2.0|8.0|16.0|32.0"
mbpt_txt = [x for x in df_init.columns if re.search(subs, str(x))]

feature_mask = baseline + baseline_txt + mbpt_txt

X_train = train_set[feature_mask].values
y_train = train_set['Asthma'].values
dtrain = xgb.DMatrix(X_train, label=y_train)

X_test = test_set[feature_mask].values
y_test = test_set['Asthma'].values
dtest = xgb.DMatrix(X_test, label=y_test)


model_xgb = xgb.train(params, dtrain, 
                    num_boost_round=20000, 
                    evals=[(dtest, 'test')], 
                    verbose_eval=0, 
                    early_stopping_rounds=1000)

print("Train accuracy", accuracy_score(y_train, model_xgb.predict(dtrain) > 0.5))
print("Test accuracy", accuracy_score(y_test, model_xgb.predict(dtest) > 0.5))
print("Train neg_loss : ", log_loss(y_pred=model_xgb.predict(dtrain), y_true=y_train))
print("Test neg_loss", log_loss(y_pred=model_xgb.predict(dtest), y_true=y_test))

y_hat = model_xgb.predict(dtest)

print(performances_hard_decision(y_test, y_hat, youden=True))

plot_roc_prc(y_hat, y_test)

explainer = shap.TreeExplainer(model_xgb)
shap_values = explainer.shap_values(X_test)

shap.summary_plot(shap_values, X_test, plot_type="bar", feature_names=feature_mask, plot_size=(10, 10))

shap.summary_plot(shap_values, X_test, feature_names=feature_mask, plot_size=(10, 10))
# Out:
# Train accuracy 0.9077181208053692
# Test accuracy 0.8533333333333334
# Train neg_loss :  0.25656138928044564
# Test neg_loss 0.35970863569527867
# AUROC: 0.912
# AUPRC: 0.903
# specificity: 0.876
# sensitivity: 0.820
# PPV: 0.820
# NPV: 0.876
# f1: 0.820
# accuracy: 0.853
# threshold: 0.399
# None

# %% [markdown]
# ## Comparison

# %%
baseline_pc16_metric['variable'] = 'MBPT_result + PC20_16'
baseline_feno_metric['variable'] = 'MBPT_result + FeNO'
# baseline_ise_metric['variable'] = 'MBPT_result + ISE_Eos'
baseline_feno_ise_metric['variable'] = 'MBPT_result + FeNO + ISE_Eos'
mbpt_txt_metric['variable'] = "MBPT_text"
mbpt_txt_feno_metric['variable'] = "MBPT_text + FeNO"
mbpt_txt_ise_metric['variable'] = "MBPT_text + ISE_Eos"
mbpt_txt_feno_ise_metric['variable'] = "MBPT_text + FeNO + ISE_Eos"

fig1_metrics = pd.concat([baseline_pc16_metric, baseline_feno_metric, 
                          baseline_feno_ise_metric, mbpt_txt_metric], axis=0).reset_index(drop=True)
fig2_metrics = pd.concat([mbpt_txt_metric, mbpt_txt_feno_metric, 
                          mbpt_txt_ise_metric, mbpt_txt_feno_ise_metric], axis=0).reset_index(drop=True)

# %%
from itertools import combinations
from statannot import add_stat_annotation
import seaborn as sns

plt.figure(figsize=(10,10))
x = 'variable'
y = 'test_auroc'
order = ['MBPT_result + PC20_16', 'MBPT_result + FeNO', 
         'MBPT_result + FeNO + ISE_Eos', "MBPT_text"]

combination = combinations(order, 2)
ax = sns.boxplot(data=fig1_metrics, x=x, y=y, order=order)

ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
# plt.ylim(0.89, 0.95)
plt.xlabel("")
plt.ylabel('AUROC', fontsize=20)
sns.despine()

# %% [markdown]
# ## AUROC

# %%
from itertools import combinations
from statannot import add_stat_annotation
import seaborn as sns

plt.figure(figsize=(10,10))
x = 'variable'
y = 'test_auroc'
order = ['MBPT_result + PC20_16', 'MBPT_result + FeNO', 
         'MBPT_result + FeNO + ISE_Eos', "MBPT_text"]

combination = combinations(order, 2)
ax = sns.boxplot(data=fig1_metrics, x=x, y=y, order=order)

ax, test_results = add_stat_annotation(ax, data=fig1_metrics, x=x, y=y, order=order,
                                   box_pairs=combination,
                                   test='t-test_ind', text_format='star', loc='outside', verbose=2)


ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
# plt.ylim(0.89, 0.95)
plt.xlabel("")
plt.ylabel('AUROC', fontsize=20)
sns.despine()
# Out:
# p-value annotation legend:
# ns: 5.00e-02 < p <= 1.00e+00
# *: 1.00e-02 < p <= 5.00e-02
# **: 1.00e-03 < p <= 1.00e-02
# ***: 1.00e-04 < p <= 1.00e-03
# ****: p <= 1.00e-04
#
# MBPT_result + PC20_16 v.s. MBPT_result + FeNO: t-test independent samples with Bonferroni correction, P_val=2.069e-56 stat=-6.849e+01
# MBPT_result + FeNO v.s. MBPT_result + FeNO + ISE_Eos: t-test independent samples with Bonferroni correction, P_val=1.483e-22 stat=-1.631e+01
# MBPT_result + FeNO + ISE_Eos v.s. MBPT_text: t-test independent samples with Bonferroni correction, P_val=4.613e-04 stat=4.256e+00
# MBPT_result + PC20_16 v.s. MBPT_result + FeNO + ISE_Eos: t-test independent samples with Bonferroni correction, P_val=1.345e-52 stat=-5.875e+01
# MBPT_result + FeNO v.s. MBPT_text: t-test independent samples with Bonferroni correction, P_val=1.301e-10 stat=-8.269e+00
# MBPT_result + PC20_16 v.s. MBPT_text: t-test independent samples with Bonferroni correction, P_val=5.882e-46 stat=-4.487e+01

# %%
fig2_metrics['variable'].value_counts()
# Out:
# MBPT_text + FeNO              30
# MBPT_text + ISE_Eos           30
# MBPT_text + FeNO + ISE_Eos    30
# MBPT_text                     30
# Name: variable, dtype: int64

# %%
from itertools import combinations
from statannot import add_stat_annotation
import seaborn as sns

plt.figure(figsize=(10,10))
x = 'variable'
y = 'test_auroc'
order = ['MBPT_text', 'MBPT_text + FeNO', 'MBPT_text + ISE_Eos',
         'MBPT_text + FeNO + ISE_Eos']

combination = combinations(order, 2)
ax = sns.boxplot(data=fig2_metrics, x=x, y=y, order=order)

ax, test_results = add_stat_annotation(ax, data=fig2_metrics, x=x, y=y, order=order,
                                   box_pairs=combination,
                                   test='t-test_ind', text_format='star', loc='outside', verbose=2)


ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
# plt.ylim(0.89, 0.95)
plt.xlabel("")
plt.ylabel('AUROC', fontsize=20)
sns.despine()
# Out:
# p-value annotation legend:
# ns: 5.00e-02 < p <= 1.00e+00
# *: 1.00e-02 < p <= 5.00e-02
# **: 1.00e-03 < p <= 1.00e-02
# ***: 1.00e-04 < p <= 1.00e-03
# ****: p <= 1.00e-04
#
# MBPT_text v.s. MBPT_text + FeNO: t-test independent samples with Bonferroni correction, P_val=5.499e-03 stat=3.495e+00
# MBPT_text + FeNO v.s. MBPT_text + ISE_Eos: t-test independent samples with Bonferroni correction, P_val=6.020e-19 stat=-1.362e+01
# MBPT_text + ISE_Eos v.s. MBPT_text + FeNO + ISE_Eos: t-test independent samples with Bonferroni correction, P_val=6.636e-05 stat=4.812e+00
# MBPT_text v.s. MBPT_text + ISE_Eos: t-test independent samples with Bonferroni correction, P_val=3.343e-11 stat=-8.624e+00
# MBPT_text + FeNO v.s. MBPT_text + FeNO + ISE_Eos: t-test independent samples with Bonferroni correction, P_val=5.323e-09 stat=-7.309e+00
# MBPT_text v.s. MBPT_text + FeNO + ISE_Eos: t-test independent samples with Bonferroni correction, P_val=5.934e-03 stat=-3.470e+00

# %% [markdown]
# ## AUPRC

# %%
from itertools import combinations
from statannot import add_stat_annotation
import seaborn as sns

plt.figure(figsize=(10,10))
x = 'variable'
y = 'test_auprc'
order = ['MBPT_result + PC20_16', 'MBPT_result + FeNO', 
         'MBPT_result + FeNO + ISE_Eos', "MBPT_text"]

combination = combinations(order, 2)
ax = sns.boxplot(data=fig1_metrics, x=x, y=y, order=order)

ax, test_results = add_stat_annotation(ax, data=fig1_metrics, x=x, y=y, order=order,
                                   box_pairs=combination,
                                   test='t-test_ind', text_format='star', loc='outside', verbose=2)


ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
# plt.ylim(0.89, 0.95)
plt.xlabel("")
plt.ylabel('AUPRC', fontsize=20)
sns.despine()
# Out:
# p-value annotation legend:
# ns: 5.00e-02 < p <= 1.00e+00
# *: 1.00e-02 < p <= 5.00e-02
# **: 1.00e-03 < p <= 1.00e-02
# ***: 1.00e-04 < p <= 1.00e-03
# ****: p <= 1.00e-04
#
# MBPT_result + PC20_16 v.s. MBPT_result + FeNO: t-test independent samples with Bonferroni correction, P_val=2.826e-43 stat=-4.020e+01
# MBPT_result + FeNO v.s. MBPT_result + FeNO + ISE_Eos: t-test independent samples with Bonferroni correction, P_val=3.493e-31 stat=-2.416e+01
# MBPT_result + FeNO + ISE_Eos v.s. MBPT_text: t-test independent samples with Bonferroni correction, P_val=7.645e-21 stat=1.500e+01
# MBPT_result + PC20_16 v.s. MBPT_result + FeNO + ISE_Eos: t-test independent samples with Bonferroni correction, P_val=1.642e-47 stat=-4.781e+01
# MBPT_result + FeNO v.s. MBPT_text: t-test independent samples with Bonferroni correction, P_val=1.000e+00 stat=5.051e-01
# MBPT_result + PC20_16 v.s. MBPT_text: t-test independent samples with Bonferroni correction, P_val=2.447e-40 stat=-3.561e+01

# %%
from itertools import combinations
from statannot import add_stat_annotation
import seaborn as sns

plt.figure(figsize=(10,10))
x = 'variable'
y = 'test_auprc'
order = ['MBPT_text', 'MBPT_text + FeNO', 'MBPT_text + ISE_Eos',
         'MBPT_text + FeNO + ISE_Eos']

combination = combinations(order, 2)
ax = sns.boxplot(data=fig2_metrics, x=x, y=y, order=order)

ax, test_results = add_stat_annotation(ax, data=fig2_metrics, x=x, y=y, order=order,
                                   box_pairs=combination,
                                   test='t-test_ind', text_format='star', loc='outside', verbose=2)


ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
# plt.ylim(0.89, 0.95)
plt.xlabel("")
plt.ylabel('AUPRC', fontsize=20)
sns.despine()
# Out:
# p-value annotation legend:
# ns: 5.00e-02 < p <= 1.00e+00
# *: 1.00e-02 < p <= 5.00e-02
# **: 1.00e-03 < p <= 1.00e-02
# ***: 1.00e-04 < p <= 1.00e-03
# ****: p <= 1.00e-04
#
# MBPT_text v.s. MBPT_text + FeNO: t-test independent samples with Bonferroni correction, P_val=1.000e+00 stat=4.725e-02
# MBPT_text + FeNO v.s. MBPT_text + ISE_Eos: t-test independent samples with Bonferroni correction, P_val=3.754e-16 stat=-1.172e+01
# MBPT_text + ISE_Eos v.s. MBPT_text + FeNO + ISE_Eos: t-test independent samples with Bonferroni correction, P_val=1.000e+00 stat=7.731e-01
# MBPT_text v.s. MBPT_text + ISE_Eos: t-test independent samples with Bonferroni correction, P_val=2.633e-12 stat=-9.292e+00
# MBPT_text + FeNO v.s. MBPT_text + FeNO + ISE_Eos: t-test independent samples with Bonferroni correction, P_val=8.307e-15 stat=-1.085e+01
# MBPT_text v.s. MBPT_text + FeNO + ISE_Eos: t-test independent samples with Bonferroni correction, P_val=3.783e-11 stat=-8.591e+00

# %% [markdown]
# ## Sensitivity

# %%
from itertools import combinations
from statannot import add_stat_annotation
import seaborn as sns

plt.figure(figsize=(10,10))
x = 'variable'
y = 'test_sensitivity'
order = ['MBPT_result + PC20_16', 'MBPT_result + FeNO', 
         'MBPT_result + FeNO + ISE_Eos', "MBPT_text"]

combination = combinations(order, 2)
ax = sns.boxplot(data=fig1_metrics, x=x, y=y, order=order)

ax, test_results = add_stat_annotation(ax, data=fig1_metrics, x=x, y=y, order=order,
                                   box_pairs=combination,
                                   test='t-test_ind', text_format='star', loc='outside', verbose=2)


ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
# plt.ylim(0.89, 0.95)
plt.xlabel("")
plt.ylabel('Sensitivity', fontsize=20)
sns.despine()
# Out:
# p-value annotation legend:
# ns: 5.00e-02 < p <= 1.00e+00
# *: 1.00e-02 < p <= 5.00e-02
# **: 1.00e-03 < p <= 1.00e-02
# ***: 1.00e-04 < p <= 1.00e-03
# ****: p <= 1.00e-04
#
# MBPT_result + PC20_16 v.s. MBPT_result + FeNO: t-test independent samples with Bonferroni correction, P_val=4.524e-13 stat=-9.761e+00
# MBPT_result + FeNO v.s. MBPT_result + FeNO + ISE_Eos: t-test independent samples with Bonferroni correction, P_val=5.895e-08 stat=-6.687e+00
# MBPT_result + FeNO + ISE_Eos v.s. MBPT_text: t-test independent samples with Bonferroni correction, P_val=1.000e+00 stat=6.878e-01
# MBPT_result + PC20_16 v.s. MBPT_result + FeNO + ISE_Eos: t-test independent samples with Bonferroni correction, P_val=4.250e-47 stat=-4.701e+01
# MBPT_result + FeNO v.s. MBPT_text: t-test independent samples with Bonferroni correction, P_val=2.013e-03 stat=-3.812e+00
# MBPT_result + PC20_16 v.s. MBPT_text: t-test independent samples with Bonferroni correction, P_val=2.403e-17 stat=-1.252e+01

# %%
from itertools import combinations
from statannot import add_stat_annotation
import seaborn as sns

plt.figure(figsize=(10,10))
x = 'variable'
y = 'test_sensitivity'
order = ['MBPT_text', 'MBPT_text + FeNO', 'MBPT_text + ISE_Eos',
         'MBPT_text + FeNO + ISE_Eos']

combination = combinations(order, 2)
ax = sns.boxplot(data=fig2_metrics, x=x, y=y, order=order)

ax, test_results = add_stat_annotation(ax, data=fig2_metrics, x=x, y=y, order=order,
                                   box_pairs=combination,
                                   test='t-test_ind', text_format='star', loc='outside', verbose=2)


ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
# plt.ylim(0.89, 0.95)
plt.xlabel("")
plt.ylabel('Sensitivity', fontsize=20)
sns.despine()
# Out:
# p-value annotation legend:
# ns: 5.00e-02 < p <= 1.00e+00
# *: 1.00e-02 < p <= 5.00e-02
# **: 1.00e-03 < p <= 1.00e-02
# ***: 1.00e-04 < p <= 1.00e-03
# ****: p <= 1.00e-04
#
# MBPT_text v.s. MBPT_text + FeNO: t-test independent samples with Bonferroni correction, P_val=6.151e-01 stat=1.659e+00
# MBPT_text + FeNO v.s. MBPT_text + ISE_Eos: t-test independent samples with Bonferroni correction, P_val=9.069e-03 stat=-3.331e+00
# MBPT_text + ISE_Eos v.s. MBPT_text + FeNO + ISE_Eos: t-test independent samples with Bonferroni correction, P_val=1.849e-01 stat=2.213e+00
# MBPT_text v.s. MBPT_text + ISE_Eos: t-test independent samples with Bonferroni correction, P_val=1.000e+00 stat=-1.184e+00
# MBPT_text + FeNO v.s. MBPT_text + FeNO + ISE_Eos: t-test independent samples with Bonferroni correction, P_val=1.000e+00 stat=-3.480e-01
# MBPT_text v.s. MBPT_text + FeNO + ISE_Eos: t-test independent samples with Bonferroni correction, P_val=1.000e+00 stat=1.018e+00

# %% [markdown]
# ## Specificity

# %%
from itertools import combinations
from statannot import add_stat_annotation
import seaborn as sns

plt.figure(figsize=(10,10))
x = 'variable'
y = 'test_specificity'
order = ['MBPT_result + PC20_16', 'MBPT_result + FeNO', 
         'MBPT_result + FeNO + ISE_Eos', "MBPT_text"]

combination = combinations(order, 2)
ax = sns.boxplot(data=fig1_metrics, x=x, y=y, order=order)

ax, test_results = add_stat_annotation(ax, data=fig1_metrics, x=x, y=y, order=order,
                                   box_pairs=combination,
                                   test='t-test_ind', text_format='star', loc='outside', verbose=2)


ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
# plt.ylim(0.89, 0.95)
plt.xlabel("")
plt.ylabel('Specificity', fontsize=20)
sns.despine()
# Out:
# p-value annotation legend:
# ns: 5.00e-02 < p <= 1.00e+00
# *: 1.00e-02 < p <= 5.00e-02
# **: 1.00e-03 < p <= 1.00e-02
# ***: 1.00e-04 < p <= 1.00e-03
# ****: p <= 1.00e-04
#
# MBPT_result + PC20_16 v.s. MBPT_result + FeNO: t-test independent samples with Bonferroni correction, P_val=2.495e-09 stat=7.505e+00
# MBPT_result + FeNO v.s. MBPT_result + FeNO + ISE_Eos: t-test independent samples with Bonferroni correction, P_val=3.769e-01 stat=-1.897e+00
# MBPT_result + FeNO + ISE_Eos v.s. MBPT_text: t-test independent samples with Bonferroni correction, P_val=1.234e-05 stat=5.275e+00
# MBPT_result + PC20_16 v.s. MBPT_result + FeNO + ISE_Eos: t-test independent samples with Bonferroni correction, P_val=2.423e-24 stat=1.775e+01
# MBPT_result + FeNO v.s. MBPT_text: t-test independent samples with Bonferroni correction, P_val=1.194e-01 stat=2.395e+00
# MBPT_result + PC20_16 v.s. MBPT_text: t-test independent samples with Bonferroni correction, P_val=1.507e-15 stat=1.133e+01

# %%
from itertools import combinations
from statannot import add_stat_annotation
import seaborn as sns

plt.figure(figsize=(10,10))
x = 'variable'
y = 'test_specificity'
order = ['MBPT_text', 'MBPT_text + FeNO', 'MBPT_text + ISE_Eos',
         'MBPT_text + FeNO + ISE_Eos']

combination = combinations(order, 2)
ax = sns.boxplot(data=fig2_metrics, x=x, y=y, order=order)

ax, test_results = add_stat_annotation(ax, data=fig2_metrics, x=x, y=y, order=order,
                                   box_pairs=combination,
                                   test='t-test_ind', text_format='star', loc='outside', verbose=2)


ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
# plt.ylim(0.89, 0.95)
plt.xlabel("")
plt.ylabel('Specificity', fontsize=20)
sns.despine()
# Out:
# p-value annotation legend:
# ns: 5.00e-02 < p <= 1.00e+00
# *: 1.00e-02 < p <= 5.00e-02
# **: 1.00e-03 < p <= 1.00e-02
# ***: 1.00e-04 < p <= 1.00e-03
# ****: p <= 1.00e-04
#
# MBPT_text v.s. MBPT_text + FeNO: t-test independent samples with Bonferroni correction, P_val=1.000e+00 stat=1.093e+00
# MBPT_text + FeNO v.s. MBPT_text + ISE_Eos: t-test independent samples with Bonferroni correction, P_val=1.271e-03 stat=-3.954e+00
# MBPT_text + ISE_Eos v.s. MBPT_text + FeNO + ISE_Eos: t-test independent samples with Bonferroni correction, P_val=1.000e+00 stat=8.322e-01
# MBPT_text v.s. MBPT_text + ISE_Eos: t-test independent samples with Bonferroni correction, P_val=1.784e-01 stat=-2.229e+00
# MBPT_text + FeNO v.s. MBPT_text + FeNO + ISE_Eos: t-test independent samples with Bonferroni correction, P_val=7.453e-02 stat=-2.580e+00
# MBPT_text v.s. MBPT_text + FeNO + ISE_Eos: t-test independent samples with Bonferroni correction, P_val=1.000e+00 stat=-1.273e+00

# %% [markdown]
# ## PPV

# %%
from itertools import combinations
from statannot import add_stat_annotation
import seaborn as sns

plt.figure(figsize=(10,10))
x = 'variable'
y = 'test_ppv'
order = ['MBPT_result + PC20_16', 'MBPT_result + FeNO', 
         'MBPT_result + FeNO + ISE_Eos', "MBPT_text"]

combination = combinations(order, 2)
ax = sns.boxplot(data=fig1_metrics, x=x, y=y, order=order)

ax, test_results = add_stat_annotation(ax, data=fig1_metrics, x=x, y=y, order=order,
                                   box_pairs=combination,
                                   test='t-test_ind', text_format='star', loc='outside', verbose=2)


ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
# plt.ylim(0.89, 0.95)
plt.xlabel("")
plt.ylabel('PPV', fontsize=20)
sns.despine()
# Out:
# p-value annotation legend:
# ns: 5.00e-02 < p <= 1.00e+00
# *: 1.00e-02 < p <= 5.00e-02
# **: 1.00e-03 < p <= 1.00e-02
# ***: 1.00e-04 < p <= 1.00e-03
# ****: p <= 1.00e-04
#
# MBPT_result + PC20_16 v.s. MBPT_result + FeNO: t-test independent samples with Bonferroni correction, P_val=3.151e-09 stat=7.444e+00
# MBPT_result + FeNO v.s. MBPT_result + FeNO + ISE_Eos: t-test independent samples with Bonferroni correction, P_val=2.171e-01 stat=-2.145e+00
# MBPT_result + FeNO + ISE_Eos v.s. MBPT_text: t-test independent samples with Bonferroni correction, P_val=5.558e-07 stat=6.102e+00
# MBPT_result + PC20_16 v.s. MBPT_result + FeNO + ISE_Eos: t-test independent samples with Bonferroni correction, P_val=2.207e-25 stat=1.864e+01
# MBPT_result + FeNO v.s. MBPT_text: t-test independent samples with Bonferroni correction, P_val=1.996e-01 stat=2.181e+00
# MBPT_result + PC20_16 v.s. MBPT_text: t-test independent samples with Bonferroni correction, P_val=1.677e-18 stat=1.331e+01

# %%
from itertools import combinations
from statannot import add_stat_annotation
import seaborn as sns

plt.figure(figsize=(10,10))
x = 'variable'
y = 'test_ppv'
order = ['MBPT_text', 'MBPT_text + FeNO', 'MBPT_text + ISE_Eos',
         'MBPT_text + FeNO + ISE_Eos']

combination = combinations(order, 2)
ax = sns.boxplot(data=fig2_metrics, x=x, y=y, order=order)

ax, test_results = add_stat_annotation(ax, data=fig2_metrics, x=x, y=y, order=order,
                                   box_pairs=combination,
                                   test='t-test_ind', text_format='star', loc='outside', verbose=2)


ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
# plt.ylim(0.89, 0.95)
plt.xlabel("")
plt.ylabel('PPV', fontsize=20)
sns.despine()
# Out:
# p-value annotation legend:
# ns: 5.00e-02 < p <= 1.00e+00
# *: 1.00e-02 < p <= 5.00e-02
# **: 1.00e-03 < p <= 1.00e-02
# ***: 1.00e-04 < p <= 1.00e-03
# ****: p <= 1.00e-04
#
# MBPT_text v.s. MBPT_text + FeNO: t-test independent samples with Bonferroni correction, P_val=4.019e-01 stat=1.867e+00
# MBPT_text + FeNO v.s. MBPT_text + ISE_Eos: t-test independent samples with Bonferroni correction, P_val=1.297e-05 stat=-5.262e+00
# MBPT_text + ISE_Eos v.s. MBPT_text + FeNO + ISE_Eos: t-test independent samples with Bonferroni correction, P_val=1.000e+00 stat=1.155e+00
# MBPT_text v.s. MBPT_text + ISE_Eos: t-test independent samples with Bonferroni correction, P_val=5.220e-02 stat=-2.716e+00
# MBPT_text + FeNO v.s. MBPT_text + FeNO + ISE_Eos: t-test independent samples with Bonferroni correction, P_val=9.181e-03 stat=-3.327e+00
# MBPT_text v.s. MBPT_text + FeNO + ISE_Eos: t-test independent samples with Bonferroni correction, P_val=1.000e+00 stat=-1.368e+00

# %% [markdown]
# ## NPV

# %%
from itertools import combinations
from statannot import add_stat_annotation
import seaborn as sns

plt.figure(figsize=(10,10))
x = 'variable'
y = 'test_npv'
order = ['MBPT_result + PC20_16', 'MBPT_result + FeNO', 
         'MBPT_result + FeNO + ISE_Eos', "MBPT_text"]

combination = combinations(order, 2)
ax = sns.boxplot(data=fig1_metrics, x=x, y=y, order=order)

ax, test_results = add_stat_annotation(ax, data=fig1_metrics, x=x, y=y, order=order,
                                   box_pairs=combination,
                                   test='t-test_ind', text_format='star', loc='outside', verbose=2)


ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
# plt.ylim(0.89, 0.95)
plt.xlabel("")
plt.ylabel('NPV', fontsize=20)
sns.despine()
# Out:
# p-value annotation legend:
# ns: 5.00e-02 < p <= 1.00e+00
# *: 1.00e-02 < p <= 5.00e-02
# **: 1.00e-03 < p <= 1.00e-02
# ***: 1.00e-04 < p <= 1.00e-03
# ****: p <= 1.00e-04
#
# MBPT_result + PC20_16 v.s. MBPT_result + FeNO: t-test independent samples with Bonferroni correction, P_val=7.516e-14 stat=-1.025e+01
# MBPT_result + FeNO v.s. MBPT_result + FeNO + ISE_Eos: t-test independent samples with Bonferroni correction, P_val=5.229e-13 stat=-9.723e+00
# MBPT_result + FeNO + ISE_Eos v.s. MBPT_text: t-test independent samples with Bonferroni correction, P_val=7.459e-01 stat=1.559e+00
# MBPT_result + PC20_16 v.s. MBPT_result + FeNO + ISE_Eos: t-test independent samples with Bonferroni correction, P_val=5.485e-47 stat=-4.680e+01
# MBPT_result + FeNO v.s. MBPT_text: t-test independent samples with Bonferroni correction, P_val=6.839e-04 stat=-4.140e+00
# MBPT_result + PC20_16 v.s. MBPT_text: t-test independent samples with Bonferroni correction, P_val=3.210e-15 stat=-1.111e+01

# %%
from itertools import combinations
from statannot import add_stat_annotation
import seaborn as sns

plt.figure(figsize=(10,10))
x = 'variable'
y = 'test_npv'
order = ['MBPT_text', 'MBPT_text + FeNO', 'MBPT_text + ISE_Eos',
         'MBPT_text + FeNO + ISE_Eos']

combination = combinations(order, 2)
ax = sns.boxplot(data=fig2_metrics, x=x, y=y, order=order)

ax, test_results = add_stat_annotation(ax, data=fig2_metrics, x=x, y=y, order=order,
                                   box_pairs=combination,
                                   test='t-test_ind', text_format='star', loc='outside', verbose=2)


ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
# plt.ylim(0.89, 0.95)
plt.xlabel("")
plt.ylabel('NPV', fontsize=20)
sns.despine()
# Out:
# p-value annotation legend:
# ns: 5.00e-02 < p <= 1.00e+00
# *: 1.00e-02 < p <= 5.00e-02
# **: 1.00e-03 < p <= 1.00e-02
# ***: 1.00e-04 < p <= 1.00e-03
# ****: p <= 1.00e-04
#
# MBPT_text v.s. MBPT_text + FeNO: t-test independent samples with Bonferroni correction, P_val=1.435e-01 stat=2.319e+00
# MBPT_text + FeNO v.s. MBPT_text + ISE_Eos: t-test independent samples with Bonferroni correction, P_val=9.742e-05 stat=-4.704e+00
# MBPT_text + ISE_Eos v.s. MBPT_text + FeNO + ISE_Eos: t-test independent samples with Bonferroni correction, P_val=5.683e-02 stat=2.684e+00
# MBPT_text v.s. MBPT_text + ISE_Eos: t-test independent samples with Bonferroni correction, P_val=5.130e-01 stat=-1.749e+00
# MBPT_text + FeNO v.s. MBPT_text + FeNO + ISE_Eos: t-test independent samples with Bonferroni correction, P_val=1.000e+00 stat=-1.164e+00
# MBPT_text v.s. MBPT_text + FeNO + ISE_Eos: t-test independent samples with Bonferroni correction, P_val=1.000e+00 stat=9.146e-01

# %% [markdown]
# ## F1 Score

# %%
from itertools import combinations
from statannot import add_stat_annotation
import seaborn as sns

plt.figure(figsize=(10,10))
x = 'variable'
y = 'test_f1'
order = ['MBPT_result + PC20_16', 'MBPT_result + FeNO', 
         'MBPT_result + FeNO + ISE_Eos', "MBPT_text"]

combination = combinations(order, 2)
ax = sns.boxplot(data=fig1_metrics, x=x, y=y, order=order)

ax, test_results = add_stat_annotation(ax, data=fig1_metrics, x=x, y=y, order=order,
                                   box_pairs=combination,
                                   test='t-test_ind', text_format='star', loc='outside', verbose=2)


ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
# plt.ylim(0.89, 0.95)
plt.xlabel("")
plt.ylabel('F1 Score', fontsize=20)
sns.despine()
# Out:
# p-value annotation legend:
# ns: 5.00e-02 < p <= 1.00e+00
# *: 1.00e-02 < p <= 5.00e-02
# **: 1.00e-03 < p <= 1.00e-02
# ***: 1.00e-04 < p <= 1.00e-03
# ****: p <= 1.00e-04
#
# MBPT_result + PC20_16 v.s. MBPT_result + FeNO: t-test independent samples with Bonferroni correction, P_val=1.569e-03 stat=-3.889e+00
# MBPT_result + FeNO v.s. MBPT_result + FeNO + ISE_Eos: t-test independent samples with Bonferroni correction, P_val=2.490e-32 stat=-2.539e+01
# MBPT_result + FeNO + ISE_Eos v.s. MBPT_text: t-test independent samples with Bonferroni correction, P_val=1.625e-15 stat=1.131e+01
# MBPT_result + PC20_16 v.s. MBPT_result + FeNO + ISE_Eos: t-test independent samples with Bonferroni correction, P_val=1.540e-54 stat=-6.353e+01
# MBPT_result + FeNO v.s. MBPT_text: t-test independent samples with Bonferroni correction, P_val=1.175e-02 stat=-3.244e+00
# MBPT_result + PC20_16 v.s. MBPT_text: t-test independent samples with Bonferroni correction, P_val=1.157e-06 stat=-5.908e+00

# %%
from itertools import combinations
from statannot import add_stat_annotation
import seaborn as sns

plt.figure(figsize=(10,10))
x = 'variable'
y = 'test_f1'
order = ['MBPT_text', 'MBPT_text + FeNO', 'MBPT_text + ISE_Eos',
         'MBPT_text + FeNO + ISE_Eos']

combination = combinations(order, 2)
ax = sns.boxplot(data=fig2_metrics, x=x, y=y, order=order)

ax, test_results = add_stat_annotation(ax, data=fig2_metrics, x=x, y=y, order=order,
                                   box_pairs=combination,
                                   test='t-test_ind', text_format='star', loc='outside', verbose=2)


ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
# plt.ylim(0.89, 0.95)
plt.xlabel("")
plt.ylabel('F1 Score', fontsize=20)
sns.despine()
# Out:
# p-value annotation legend:
# ns: 5.00e-02 < p <= 1.00e+00
# *: 1.00e-02 < p <= 5.00e-02
# **: 1.00e-03 < p <= 1.00e-02
# ***: 1.00e-04 < p <= 1.00e-03
# ****: p <= 1.00e-04
#
# MBPT_text v.s. MBPT_text + FeNO: t-test independent samples with Bonferroni correction, P_val=5.013e-05 stat=4.890e+00
# MBPT_text + FeNO v.s. MBPT_text + ISE_Eos: t-test independent samples with Bonferroni correction, P_val=6.149e-19 stat=-1.362e+01
# MBPT_text + ISE_Eos v.s. MBPT_text + FeNO + ISE_Eos: t-test independent samples with Bonferroni correction, P_val=3.383e-08 stat=6.831e+00
# MBPT_text v.s. MBPT_text + ISE_Eos: t-test independent samples with Bonferroni correction, P_val=3.915e-08 stat=-6.793e+00
# MBPT_text + FeNO v.s. MBPT_text + FeNO + ISE_Eos: t-test independent samples with Bonferroni correction, P_val=1.532e-05 stat=-5.216e+00
# MBPT_text v.s. MBPT_text + FeNO + ISE_Eos: t-test independent samples with Bonferroni correction, P_val=1.000e+00 stat=-1.516e-01
